# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiofonv/aluraDataScience/blob/master/intro_ia_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('ALURA_AULA')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model="gemini-2.5-flash", contents="O que é IA?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar sistemas e máquinas capazes de realizar tarefas que, historicamente, exigiriam inteligência humana. Em termos mais simples, é a capacidade de um programa de computador pensar, aprender, raciocinar, perceber, compreender a linguagem e resolver problemas de forma semelhante aos seres humanos.
#
# ### Como funciona (em linhas gerais):
#
# A IA funciona através da análise de grandes volumes de dados (big data) para identificar padrões, aprender com eles e, com base nesse aprendizado, fazer previsões, tomar decisões ou executar ações. Em vez de ser explicitamente programada para cada cenário possível, a IA é treinada para aprender e adaptar-se.
#
# ### Principais Pilares e Áreas da IA:
#
# 1.  **Machine Learning (Aprendizagem de Máquina):** É o motor da IA moderna. Permite que os sistemas aprendam a partir de dados, identifiquem padrões e tomem decisões com o mínimo de intervenção humana.
# ...
